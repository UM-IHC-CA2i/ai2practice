# %% [markdown]
# # Research Module 1: Getting Started with Python
#
# **AI-Ready Radiology Curriculum**
#
# Welcome! In this notebook you will:
# 1. Learn basic Python: variables, types, lists, loops, and functions
# 2. Load a dataset using pandas
# 3. Explore the data with basic commands
# 4. Create a simple chart
# 5. Complete hands-on tasks and commit your work to GitHub
#
# ---
#
# **No prior programming experience is required.** Run cells in order by clicking the play button or pressing `Shift + Enter`.

# %% [markdown]
# ## Part 1: Python Basics
#
# Python is the most widely used language in AI research. Let's start with the fundamentals.

# %% [markdown]
# ### Variables and Types
#
# A **variable** stores a value. Python figures out the type automatically.

# %%
# Strings (text)
name = 'Radiology'
print(name)
print(type(name))

# Integers (whole numbers)
num_studies = 60
print(num_studies)
print(type(num_studies))

# Floats (decimal numbers)
accuracy = 0.85
print(accuracy)
print(type(accuracy))

# Booleans (True/False)
ai_flagged = True
print(ai_flagged)
print(type(ai_flagged))

# %% [markdown]
# ### Lists
#
# A **list** holds multiple values in order. You access items by their position (starting at 0).

# %%
modalities = ['CR', 'CT', 'MR', 'US']

print('All modalities:', modalities)
print('First modality:', modalities[0])
print('Last modality:', modalities[-1])
print('Number of modalities:', len(modalities))

# %% [markdown]
# ### For Loops
#
# A **for loop** repeats an action for each item in a list.

# %%
modalities = ['CR', 'CT', 'MR', 'US']

for mod in modalities:
    print(f'{mod} is an imaging modality')

print()

# Counting with a loop
total = 0
numbers = [10, 20, 30]
for n in numbers:
    total = total + n
print(f'Sum of {numbers} = {total}')

# %% [markdown]
# ### Functions
#
# A **function** is a reusable block of code. You define it with `def` and call it by name.

# %%
def greet(name):
    return f'Welcome to AI research, {name}!'

message = greet('Dr. Smith')
print(message)

# A function that does a calculation
def percentage(part, whole):
    return round((part / whole) * 100, 1)

print(f'42 out of 60 = {percentage(42, 60)}%')

# %% [markdown]
# ### Conditionals (if/else)
#
# **Conditionals** let your code make decisions.

# %%
confidence = 0.85

if confidence >= 0.9:
    print('High confidence')
elif confidence >= 0.7:
    print('Moderate confidence')
else:
    print('Low confidence')

# %% [markdown]
# ---
#
# ## Part 2: Loading and Exploring Data
#
# Now let's use Python to work with real-format data. We will use **pandas**, a library for tabular data (like a spreadsheet in Python).

# %%
import pandas as pd
import matplotlib.pyplot as plt

print('Libraries loaded successfully!')

# %% [markdown]
# ### Load the Dataset
#
# We have a dataset of 60 radiology studies. Each row records whether an AI tool flagged a finding and whether a radiologist confirmed it.
#
# **Important:** Replace `YOUR-USERNAME` below with your actual GitHub username.

# %%
# ============================================================
# IMPORTANT: Replace YOUR-USERNAME with your GitHub username
# ============================================================
GITHUB_USERNAME = 'YOUR-USERNAME'

url = f'https://raw.githubusercontent.com/{GITHUB_USERNAME}/Bootcamp-AI-for-Medical-Imaging/main/data/radiology_ai_findings.csv'
df = pd.read_csv(url)

print(f'Loaded {len(df)} studies from {GITHUB_USERNAME}\'s repository')

# %% [markdown]
# ### Explore the Data
#
# Useful pandas commands:
# - `df.head()` — shows the first 5 rows
# - `df.shape` — gives you (rows, columns)
# - `df['column'].value_counts()` — counts how many times each value appears

# %%
# See the first 5 rows
df.head()

# %%
# How big is the dataset?
print(f'Shape: {df.shape}')
print(f'This means {df.shape[0]} rows and {df.shape[1]} columns')

# %%
# Count studies by imaging modality
print('Studies by modality:')
print(df['modality'].value_counts())

# %%
# Count studies by body region
print('Studies by body region:')
print(df['body_region'].value_counts())

# %% [markdown]
# ### Create a Bar Chart
#
# Let's visualize how many studies used each imaging modality.

# %%
counts = df['modality'].value_counts()

fig, ax = plt.subplots(figsize=(8, 5))
counts.plot(kind='bar', ax=ax, color='#0D9488')
ax.set_xlabel('Imaging Modality')
ax.set_ylabel('Number of Studies')
ax.set_title('Studies by Imaging Modality')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## Part 3: Your Turn
#
# Complete the tasks below. Each one requires you to write or modify a small amount of code.
#
# ### Task 1: Create a variable
#
# Create a variable called `my_name` with your name, and a variable called `my_modality` with your favorite imaging modality. Print both.

# %%
# ============================================================
# TASK 1: Fill in your name and favorite modality
# ============================================================
my_name = ''        # <-- Put your name here
my_modality = ''    # <-- Put a modality here (CR, CT, MR, or US)

print(f'My name is {my_name}')
print(f'My favorite modality is {my_modality}')

# %% [markdown]
# ### Task 2: Write a loop
#
# The list below contains body regions. Write a for loop that prints each one.

# %%
# ============================================================
# TASK 2: Write a for loop to print each body region
# ============================================================
regions = ['Chest', 'Abdomen', 'Head', 'MSK', 'Brain']

# Your loop here:

# %% [markdown]
# ### Task 3: Count AI-flagged studies
#
# Use `value_counts()` on the `ai_flagged` column to find out how many studies the AI flagged as positive vs. negative.

# %%
# ============================================================
# TASK 3: Count how many studies were AI-flagged (True vs False)
# ============================================================

# Your code here:

# %% [markdown]
# ### Task 4: Make a chart
#
# Create a bar chart showing the number of studies per **body region** (instead of per modality). Hint: adapt the chart code from Part 2 by changing `'modality'` to `'body_region'`.

# %%
# ============================================================
# TASK 4: Create a bar chart of studies by body region
# ============================================================

# Your code here:

# %% [markdown]
# ---
#
# ## Save Your Work
#
# Run the cell below to generate your completion record, then save your notebook to GitHub.
#
# ### How to save:
# 1. In Colab, go to **File > Download > Download .ipynb**
# 2. Go to your forked repository: `https://github.com/YOUR-USERNAME/Bootcamp-AI-for-Medical-Imaging`
# 3. Click the **Code** tab at the top
# 4. Click **Add file > Upload files**
# 5. Drag and drop your downloaded `.ipynb` file into the upload area
# 6. In the commit message box, type: `Completed Research Module 1`
# 7. Make sure **"Commit directly to the main branch"** is selected
# 8. Click **Commit changes**
#
# ### After all research modules are complete:
# When you have finished and uploaded all 5 research modules, submit your work for review:
# 1. On your fork's main page, click the **Contribute** button (near the top)
# 2. Click **Open pull request**
# 3. Add a title (e.g., "Completed all research modules") and click **Create pull request**
#
# If you need to withdraw your submission, you can close the pull request at any time from the same page.

# %%
# Completion record
from datetime import datetime

print('=' * 50)
print('RESEARCH MODULE 1 — COMPLETION RECORD')
print('=' * 50)
print(f'GitHub Username:  {GITHUB_USERNAME}')
print(f'Completed:        {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}')
print(f'Dataset Size:     {len(df)} studies')
print(f'Modalities Found: {sorted(df["modality"].unique().tolist())}')
print(f'Body Regions:     {sorted(df["body_region"].unique().tolist())}')
print('=' * 50)
print('Save this notebook to GitHub to submit your work.')
